# %%
#MLFLOW Tracking Server

# %% [markdown]
# import mlflow

# %%
import mlflow

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("Check local tracking server")
with mlflow.start_run():
    mlflow.log_metric("test1", 1)
    mlflow.log_metric("Vinny1", 1)
# Out:
# 🏃 View run masked-shrike-293 at: http://127.0.0.1:5000/#/experiments/1/runs/303b8f09ff1541578b9e8772e1e2da52
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
mlflow.set_experiment("Check local tracking server")
with mlflow.start_run():
    mlflow.log_metric("test2", 2)
    mlflow.log_metric("Vinny2", 2)
# Out:
# 🏃 View run big-fish-751 at: http://127.0.0.1:5000/#/experiments/1/runs/d208b38bea8046db834f72a6640ec530
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
